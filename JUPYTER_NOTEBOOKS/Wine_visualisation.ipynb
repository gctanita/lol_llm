# %% [markdown]
# # Wine Data Visualisation in Jupyter Notebook - using atoti
#
# Link to the tutorial: https://www.youtube.com/watch?v=Y49662c3EL4&ab_channel=LightsOnData - **Youtube: How to Create a Data Visualization in Jupyter Notebook Using atoti**

# %%
import atoti as tt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Read the data for the red and white wines

# %% [markdown]
# ## Red Wine

# %%
wine_red = pd.read_csv(
    "https://data.atoti.io/notebooks/wine-analytics/winequality-red.csv", sep=";"
)
wine_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ## White Wine

# %%
wine_white = pd.read_csv(
    "https://data.atoti.io/notebooks/wine-analytics/winequality-white.csv", sep=";"
)
wine_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# ## Add a new column "category" to the datasets

# %%
wine_red["category"] = "Red"
wine_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality category
# 0      9.4        5      Red
# ...

# %%
wine_white["category"] = "White"
wine_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality category
# 0      8.8        6    White
# ...

# %%
wines = pd.concat([wine_red, wine_white], axis=0, ignore_index=True)
wines.index.set_names("wine index", inplace=True)
wines.head()
# Out:
#             fixed acidity  volatile acidity  citric acid  residual sugar  \
# wine index
# 0                     7.4              0.70         0.00             1.9
# 1                     7.8              0.88         0.00             2.6
# 2                     7.8              0.76         0.04             2.3
# 3                    11.2              0.28         0.56             1.9
# 4                     7.4              0.70         0.00             1.9
#
#             chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# wine index
# 0               0.076                 11.0                  34.0   0.9978
# 1               0.098                 25.0                  67.0   0.9968
# 2               0.092                 15.0                  54.0   0.9970
# 3               0.075                 17.0                  60.0   0.9980
# 4               0.076                 11.0                  34.0   0.9978
#
#               pH  sulphates  alcohol  quality category
# ...

# %%
wines["alcohol range"] = wines["alcohol"].apply(np.floor)

# %%
wines["Rating"] = "Good"
wines.loc[wines["quality"] < 7, "Rating"] = "Average"
wines.loc[wines["quality"] < 5, "Rating"] = "Poor"
wines
# Out:
#             fixed acidity  volatile acidity  citric acid  residual sugar  \
# wine index
# 0                     7.4              0.70         0.00             1.9
# 1                     7.8              0.88         0.00             2.6
# 2                     7.8              0.76         0.04             2.3
# 3                    11.2              0.28         0.56             1.9
# 4                     7.4              0.70         0.00             1.9
# ...                   ...               ...          ...             ...
# 6492                  6.2              0.21         0.29             1.6
# 6493                  6.6              0.32         0.36             8.0
# 6494                  6.5              0.24         0.19             1.2
# 6495                  5.5              0.29         0.30             1.1
# 6496                  6.0              0.21         0.38             0.8
#
#             chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# ...

# %%
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### Prepare the data for corelation

# %%
onlyRedWines = wine_red[wine_red['category'] == 'Red']
redWinesReadyForCorelation = onlyRedWines.drop(columns=['category'])

# %% [markdown]
# ## Default corelation => using **Pearson** method

# %%
corr_red_pearson = redWinesReadyForCorelation.corr()
ax_red = sns.heatmap(
    corr_red_pearson,
    vmin=-1,
    vmax=1,
    center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
)
ax_red.set_xticklabels(
    ax_red.get_xticklabels(), rotation=45, horizontalalignment="right"
);

# %% [markdown]
# ## Corelation using **kendall** method

# %%
corr_red_kendall = redWinesReadyForCorelation.corr(method='kendall')
ax_red = sns.heatmap(
    corr_red_kendall,
    vmin=-1,
    vmax=1,
    center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
)
ax_red.set_xticklabels(
    ax_red.get_xticklabels(), rotation=45, horizontalalignment="right"
);

# %% [markdown]
# ## Corelation using **spearman** method

# %%
corr_red_spearman = redWinesReadyForCorelation.corr(method='spearman')
ax_red = sns.heatmap(
    corr_red_spearman,
    vmin=-1,
    vmax=1,
    center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
)
ax_red.set_xticklabels(
    ax_red.get_xticklabels(), rotation=45, horizontalalignment="right"
);

# %%
print("Pearson corelation values")
corr_red_pearson[(corr_red_pearson['quality'] > 0.25) | (corr_red_pearson['quality'] < -0.25)]["quality"]
# Out:
# Pearson corelation values
# volatile acidity   -0.390558
# sulphates           0.251397
# alcohol             0.476166
# quality             1.000000
# Name: quality, dtype: float64

# %%
print("Kendall corelation values")
corr_red_kendall[(corr_red_kendall['quality'] > 0.25) | (corr_red_kendall['quality'] < -0.25)]["quality"]
# Out:
# Kendall corelation values
# volatile acidity   -0.300779
# sulphates           0.299270
# alcohol             0.380367
# quality             1.000000
# Name: quality, dtype: float64

# %%
print("Spearman corelation values")
corr_red_spearman[(corr_red_spearman['quality'] > 0.25) | (corr_red_spearman['quality'] < -0.25)]["quality"]
# Out:
# Spearman corelation values
# volatile acidity   -0.380647
# sulphates           0.377060
# alcohol             0.478532
# quality             1.000000
# Name: quality, dtype: float64

# %% [markdown]
# Pearson
# - Linear relashiopnship - continuous variables
# - normally distributed data
# - homoscedasticity - the variability is the same between dependent and non dependent variables
#
# Spearman
# - Monotonic relashionship - continous or ordinal
# - non-parametric => does not assume data's distribution
# - variables are ranked => a ranking has to be done before the analasys is done
#
# BOTH:
# - look at linear relations (they only decrease or increase... )
# -

# %%
b
